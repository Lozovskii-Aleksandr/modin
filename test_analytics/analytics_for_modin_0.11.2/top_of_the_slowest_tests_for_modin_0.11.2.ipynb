# %% [markdown]
# Specify the folder from where you want to import json for analysis

# %%
path_dir = 'json_analytics_from_test'

# %%
# Get a list of tests in the folder
import os
list_files = tuple(os.walk(path_dir))[0][2]

# %% [markdown]
# The following block is needed to import the module from the parent folder

# %%
import os
import sys
import inspect

currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0, parentdir)

# %%
from ParseOutputPytest import ParseOutputPytest
pop = ParseOutputPytest()

# %% [markdown]
# Получим самые медленные тесты

# %%
for i in list_files:
    dict_name_duration = pop.get_dict_test_duration(f'{path_dir}/{i}')
    sorted_list_group = sorted(dict_name_duration.items(), key=lambda x: x[1], reverse=True)
    for name, duration in sorted_list_group[:10]:
        print(f'{name}\n    {duration}')
    print('\n')
# Out:
# modin/pandas/test/test_general.py::test_to_datetime_inplace_side_effect
#     253.08356500000002
# modin/pandas/test/test_general.py::test_isna[float_nan_data]
#     62.21162679999999
# modin/pandas/test/test_general.py::test_notna[float_nan_data]
#     59.26236010000002
# modin/pandas/test/test_general.py::test_notnull[float_nan_data]
#     57.23263890000001
# modin/pandas/test/test_general.py::test_isnull[float_nan_data]
#     25.604626700000026
# modin/pandas/test/test_general.py::test_to_datetime
#     2.1319135000000244
# modin/pandas/test/test_general.py::test_merge
#     0.5770831999999473
# modin/pandas/test/test_general.py::test_merge_asof_bad_arguments
#     0.2365427000000011
# modin/pandas/test/test_general.py::test_pivot
#     0.20589700000002154
# modin/pandas/test/test_general.py::test_to_pandas_indices[[]]
#     0.06814810000003035
#
#
# modin/pandas/test/test_io.py::TestCsv::test_read_csv_delimiters[None-.-_-None]
#     10.864537299999999
# modin/pandas/test/test_io.py::TestCsv::test_read_csv_s3
#     8.03661559999999
# modin/pandas/test/test_io.py::TestExcel::test_read_excel
#     1.9775033000000235
# modin/pandas/test/test_io.py::test_to_period
#     0.6725706000000571
# modin/pandas/test/test_io.py::TestExcel::test_to_excel
#     0.41455740000002095
# modin/pandas/test/test_io.py::TestSql::test_to_sql[True]
#     0.342470899999995
# modin/pandas/test/test_io.py::TestSql::test_to_sql[False]
#     0.3122460000000018
# modin/pandas/test/test_io.py::test_to_latex
#     0.30568939999997724
# modin/pandas/test/test_io.py::TestFwf::test_fwf_file_chunksize
#     0.26370560000000864
# modin/pandas/test/test_io.py::TestStata::test_to_stata
#     0.2625564999999881
#
#
# modin/pandas/test/test_groupby.py::test_agg_exceptions[cumprod]
#     95.17010640000012
# modin/pandas/test/test_groupby.py::test_agg_exceptions[unique]
#     90.16875570000008
# modin/pandas/test/test_groupby.py::test_mixed_columns_not_from_df[True-columns0]
#     0.2928559999999152
# modin/pandas/test/test_groupby.py::test_mixed_columns_not_from_df[False-columns1]
#     0.29181299999982
# modin/pandas/test/test_groupby.py::test_mixed_columns_not_from_df[False-columns0]
#     0.285109099999886
# modin/pandas/test/test_groupby.py::test_mixed_columns_not_from_df[False-columns2]
#     0.2620520000001534
# modin/pandas/test/test_groupby.py::test_mixed_columns_not_from_df[True-columns4]
#     0.25965770000004795
# modin/pandas/test/test_groupby.py::test_mixed_columns_not_from_df[True-columns1]
#     0.2585533999999825
# modin/pandas/test/test_groupby.py::test_mixed_columns_not_from_df[True-columns2]
#     0.2572003999999879
# modin/pandas/test/test_groupby.py::test_mixed_columns[columns5]
#     0.25397209999994175
#
#
# modin/pandas/test/dataframe/test_binary.py::test_math_functions[rfloordiv-columns-series_or_list]
#     107.77883190000011
# modin/pandas/test/dataframe/test_binary.py::test_math_functions[add-rows-scalar]
#     70.36442350000002
# modin/pandas/test/dataframe/test_binary.py::test_math_functions[rsub-columns-series_or_list]
#     68.96612479999987
# modin/pandas/test/dataframe/test_binary.py::test_math_functions[truediv-columns-series_or_list]
#     68.9559714999998
# modin/pandas/test/dataframe/test_binary.py::test_math_functions[rmod-columns-series_or_list]
#     68.90448959999992
# modin/pandas/test/dataframe/test_binary.py::test_math_functions[rpow-columns-series_or_list]
#     68.76874280000015
# modin/pandas/test/dataframe/test_binary.py::test_math_functions[radd-columns-series_or_list]
#     68.66964629999998
# modin/pandas/test/dataframe/test_binary.py::test_math_functions[rtruediv-columns-series_or_list]
#     68.66572050000036
# modin/pandas/test/dataframe/test_binary.py::test_math_functions[mul-columns-series_or_list]
#     68.59221370000023
# modin/pandas/test/dataframe/test_binary.py::test_math_functions[rmul-columns-series_or_list]
#     68.4957685000004
#
#
# modin/pandas/test/dataframe/test_join_sort.py::test_sort_values[None-ignore_index_None-last-quicksort-inplace_False-ascending_False-over_rows_str-first,last,middle-float_nan_data]
#     176.27858130000095
# modin/pandas/test/dataframe/test_join_sort.py::test_sort_values[rotate_decimal_digits_or_symbols-ignore_index_False-last-quicksort-inplace_None-ascending_list_first_True-over_rows_int-first,last,middle-float_nan_data]
#     149.80876560000615
# modin/pandas/test/dataframe/test_join_sort.py::test_sort_values[rotate_decimal_digits_or_symbols-ignore_index_False-first-quicksort-inplace_True-ascending_list_first_True-over_rows_int-first,last,middle-float_nan_data]
#     146.0239337999883
# modin/pandas/test/dataframe/test_join_sort.py::test_sort_values[rotate_decimal_digits_or_symbols-ignore_index_False-first-quicksort-inplace_None-ascending_True-over_rows_int-first,last,middle-float_nan_data]
#     145.91076479999901
# modin/pandas/test/dataframe/test_join_sort.py::test_sort_values[rotate_decimal_digits_or_symbols-ignore_index_False-first-quicksort-inplace_True-ascending_True-over_rows_str-first,last,middle-float_nan_data]
#     145.8890795999905
# modin/pandas/test/dataframe/test_join_sort.py::test_sort_values[rotate_decimal_digits_or_symbols-ignore_index_True-last-quicksort-inplace_True-ascending_list_first_True-over_rows_int-first,last,middle-float_nan_data]
#     145.87606629999937
# modin/pandas/test/dataframe/test_join_sort.py::test_sort_values[rotate_decimal_digits_or_symbols-ignore_index_True-last-quicksort-inplace_True-ascending_True-over_rows_int-first,last,middle-float_nan_data]
#     145.83408580000105
# modin/pandas/test/dataframe/test_join_sort.py::test_sort_values[rotate_decimal_digits_or_symbols-ignore_index_True-first-quicksort-inplace_False-ascending_False-over_rows_str-first,last,middle-float_nan_data]
#     145.78465900000083
# modin/pandas/test/dataframe/test_join_sort.py::test_sort_values[rotate_decimal_digits_or_symbols-ignore_index_True-first-quicksort-inplace_False-ascending_list_first_True-over_rows_str-first,last,middle-float_nan_data]
#     145.43868529999963
# modin/pandas/test/dataframe/test_join_sort.py::test_sort_values[rotate_decimal_digits_or_symbols-ignore_index_False-first-quicksort-inplace_True-ascending_False-over_rows_str-first,last,middle-float_nan_data]
#     145.34294399999635
#
#
# modin/pandas/test/dataframe/test_iter.py::test_isin[float_nan_data]
#     98.13010749999984
# modin/pandas/test/dataframe/test_iter.py::test_items_iteritems_iterrows[items]
#     71.7960237
# modin/pandas/test/dataframe/test_iter.py::test___copy__[float_nan_data]
#     68.22715149999999
# modin/pandas/test/dataframe/test_iter.py::test_constructor[float_nan_data]
#     61.95996559999992
# modin/pandas/test/dataframe/test_iter.py::test_inplace_series_ops[float_nan_data]
#     58.23643440000001
# modin/pandas/test/dataframe/test_iter.py::test___contains__[float_nan_data]
#     58.06887900000001
# modin/pandas/test/dataframe/test_iter.py::test_items_iteritems_iterrows[iterrows]
#     30.453193799999994
# modin/pandas/test/dataframe/test_iter.py::test___deepcopy__[float_nan_data]
#     30.351671599999975
# modin/pandas/test/dataframe/test_iter.py::test_items_iteritems_iterrows[iteritems]
#     26.961732600000005
# modin/pandas/test/dataframe/test_iter.py::test_constructor_dtypes[data2]
#     0.05521190000001752
#
#
# modin/pandas/test/dataframe/test_default.py::test_melt[None-None-float_nan_data]
#     1743.483486799999
# modin/pandas/test/dataframe/test_default.py::test_melt[None-<lambda>0-float_nan_data]
#     1690.6196296000012
# modin/pandas/test/dataframe/test_default.py::test_melt[None-<lambda>1-float_nan_data]
#     1567.2058689999985
# modin/pandas/test/dataframe/test_default.py::test_pivot[None-<lambda>-None-float_nan_data]
#     495.7832106999995
# modin/pandas/test/dataframe/test_default.py::test_pivot[<lambda>1-<lambda>-None-float_nan_data]
#     140.63392639999984
# modin/pandas/test/dataframe/test_default.py::test_shift_slice_shift[1-1-has_duplicates-float_nan_data]
#     81.37592409999888
# modin/pandas/test/dataframe/test_default.py::test_shift_slice_shift[1-0-has_duplicates-float_nan_data]
#     81.04955459999837
# modin/pandas/test/dataframe/test_default.py::test_shift_slice_shift[-1-0-has_duplicates-float_nan_data]
#     80.6898618999985
# modin/pandas/test/dataframe/test_default.py::test_shift_slice_shift[0-1-has_duplicates-float_nan_data]
#     80.53012140000101
# modin/pandas/test/dataframe/test_default.py::test_shift_slice_shift[1-0-default-float_nan_data]
#     80.46632239999781
# modin/pandas/test/dataframe/test_indexing.py::test___setitem__with_mismatched_partitions
#     189.800260299995
# modin/pandas/test/dataframe/test_indexing.py::test_iloc[float_nan_data]
#     88.34348949999998
# modin/pandas/test/dataframe/test_indexing.py::test_tail[n_1-float_nan_data]
#     68.87018270000408
# modin/pandas/test/dataframe/test_indexing.py::test___getattr__[float_nan_data]
#     60.48236350000661
# modin/pandas/test/dataframe/test_indexing.py::test_tail[n_-5-float_nan_data]
#     38.35341280000284
# modin/pandas/test/dataframe/test_indexing.py::test_tail[n_-1-float_nan_data]
#     38.32587639999838
# modin/pandas/test/dataframe/test_indexing.py::test_iloc_nested_assignment[float_nan_data]
#     37.37429650000024
# modin/pandas/test/dataframe/test_indexing.py::test_loc_nested_assignment[float_nan_data]
#     37.328570700000114
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index[float_nan_data]
#     37.07703819999972
# modin/pandas/test/dataframe/test_indexing.py::test_head[n_-5-float_nan_data]
#     36.36387759999997
#
#
# modin/pandas/test/dataframe/test_udf.py::test_agg_apply[apply-sum mean-0]
#     153.80672449999997
# modin/pandas/test/dataframe/test_udf.py::test_agg_apply[apply-sum df sum-0]
#     150.10651000000007
# modin/pandas/test/dataframe/test_udf.py::test_agg_apply[apply-sum mean-1]
#     149.20306529999993
# modin/pandas/test/dataframe/test_udf.py::test_agg_apply[agg-sum mean-0]
#     148.4365945999998
# modin/pandas/test/dataframe/test_udf.py::test_agg_apply[agg-sum df sum-0]
#     147.7330963999999
# modin/pandas/test/dataframe/test_udf.py::test_agg_apply[agg-sum mean-1]
#     147.0949701999998
# modin/pandas/test/dataframe/test_udf.py::test_transform[df sum-float_nan_data]
#     86.74492670000018
# modin/pandas/test/dataframe/test_udf.py::test_agg_apply[apply-df sum-0]
#     85.75335540000015
# modin/pandas/test/dataframe/test_udf.py::test_agg_apply[agg-df sum-0]
#     85.71296999999996
# modin/pandas/test/dataframe/test_udf.py::test_agg_apply[apply-df sum-1]
#     85.03951000000006
#
#
# modin/pandas/test/dataframe/test_window.py::test_mode[numeric_only_None-over_rows_str-float_nan_data]
#     587.9280221999998
# modin/pandas/test/dataframe/test_window.py::test_mode[numeric_only_False-over_rows_str-float_nan_data]
#     563.7540224999993
# modin/pandas/test/dataframe/test_window.py::test_mode[numeric_only_False-over_rows_int-float_nan_data]
#     560.6365420000002
# modin/pandas/test/dataframe/test_window.py::test_mode[numeric_only_None-over_rows_int-float_nan_data]
#     550.9044362000004
# modin/pandas/test/dataframe/test_window.py::test_mode[numeric_only_None-over_columns_str-float_nan_data]
#     452.7895642000012
# modin/pandas/test/dataframe/test_window.py::test_mode[numeric_only_False-over_columns_str-float_nan_data]
#     452.29137079999873
# modin/pandas/test/dataframe/test_window.py::test_mode[numeric_only_False-over_columns_int-float_nan_data]
#     449.7167023000011
# modin/pandas/test/dataframe/test_window.py::test_mode[numeric_only_None-over_columns_int-float_nan_data]
#     414.7362936000018
# modin/pandas/test/dataframe/test_window.py::test_nunique[dropna_True-over_rows_str-float_nan_data]
#     129.42218599999978
# modin/pandas/test/dataframe/test_window.py::test_nunique[dropna_None-over_rows_int-float_nan_data]
#     128.6914371999992
#
#
# modin/pandas/test/test_series.py::test_pop[float_nan_data]
#     77.25314189999983
# modin/pandas/test/test_series.py::test_sort_values[last-True-float_nan_data]
#     47.61851430000024
# modin/pandas/test/test_series.py::test_sort_values[first-True-float_nan_data]
#     46.83895280000047
# modin/pandas/test/test_series.py::test_mode[float_nan_data]
#     16.91528609999989
# modin/pandas/test/test_series.py::test___setitem__[float_nan_data]
#     15.361696599999988
# modin/pandas/test/test_series.py::test_repeat[repeats_4-float_nan_data]
#     13.434675200000356
# modin/pandas/test/test_series.py::test_repeat[repeats_2-float_nan_data]
#     12.933941800000184
# modin/pandas/test/test_series.py::test_repeat[repeats_3-float_nan_data]
#     12.918615299999601
# modin/pandas/test/test_series.py::test_rfloordiv[float_nan_data]
#     7.283974799999896
# modin/pandas/test/test_series.py::test_rank[keep-float_nan_data]
#     6.95792680000045
#
#
#
#
# modin/pandas/test/test_rolling.py::test_dataframe[None-5-100-float_nan_data]
#     196.49379820000001
# modin/pandas/test/test_rolling.py::test_dataframe[None-5-5-float_nan_data]
#     163.05918790000004
# modin/pandas/test/test_rolling.py::test_dataframe[None-None-5-float_nan_data]
#     159.2735927
# modin/pandas/test/test_rolling.py::test_dataframe[None-None-100-float_nan_data]
#     83.25327170000006
# modin/pandas/test/test_rolling.py::test_dataframe[triang-None-5-float_nan_data]
#     75.0487311999999
# modin/pandas/test/test_rolling.py::test_dataframe[triang-5-100-float_nan_data]
#     73.65858759999992
# modin/pandas/test/test_rolling.py::test_dataframe[triang-None-100-float_nan_data]
#     36.285214500000166
# modin/pandas/test/test_rolling.py::test_dataframe[triang-5-5-float_nan_data]
#     36.14272779999999
#
#
# modin/pandas/test/test_concat.py::test_concat_series_only
#     0.7759938999999996
# modin/pandas/test/test_concat.py::test_invalid_axis_errors
#     0.37984819999999964
# modin/pandas/test/test_concat.py::test_concat_with_empty_frame
#     0.18976829999999367
#
#
# modin/pandas/test/dataframe/test_map_metadata.py::test_set_index[append_True-drop_False-float_nan_data]
#     119.47122730000228
# modin/pandas/test/dataframe/test_map_metadata.py::test_set_index[append_True-drop_True-float_nan_data]
#     119.28998959999808
# modin/pandas/test/dataframe/test_map_metadata.py::test_set_index[append_True-drop_None-float_nan_data]
#     118.04033890000028
# modin/pandas/test/dataframe/test_map_metadata.py::test_applymap_numeric[square-float_nan_data]
#     107.6662990000001
# modin/pandas/test/dataframe/test_map_metadata.py::test_applymap[plus one-float_nan_data]
#     103.50122950000002
# modin/pandas/test/dataframe/test_map_metadata.py::test_dropna_inplace[float_nan_data]
#     77.23675270000149
# modin/pandas/test/dataframe/test_map_metadata.py::test_applymap[square-float_nan_data]
#     69.87382380000005
# modin/pandas/test/dataframe/test_map_metadata.py::test_applymap_numeric[plus one-float_nan_data]
#     69.45971760000003
# modin/pandas/test/dataframe/test_map_metadata.py::test_applymap_numeric[identity-float_nan_data]
#     68.90363189999994
# modin/pandas/test/dataframe/test_map_metadata.py::test_applymap_numeric[return false-float_nan_data]
#     59.47463650000009
#
#
# modin/pandas/test/dataframe/test_reduction.py::test_min_max_mean[data0-over_columns_int-skipna_False-numeric_only_True-True-mean]
#     89.82260339999812
# modin/pandas/test/dataframe/test_reduction.py::test_min_max_mean[data0-over_columns_str-skipna_False-numeric_only_True-True-mean]
#     89.60727030000089
# modin/pandas/test/dataframe/test_reduction.py::test_min_max_mean[data0-over_columns_str-skipna_False-numeric_only_None-True-mean]
#     88.80846320000092
# modin/pandas/test/dataframe/test_reduction.py::test_min_max_mean[data0-over_columns_int-skipna_False-numeric_only_None-True-mean]
#     88.79308799999671
# modin/pandas/test/dataframe/test_reduction.py::test_min_max_mean[data0-over_columns_int-skipna_None-numeric_only_False-True-max]
#     87.44708100000025
# modin/pandas/test/dataframe/test_reduction.py::test_min_max_mean[data0-over_columns_int-skipna_None-numeric_only_False-True-min]
#     87.10220450000088
# modin/pandas/test/dataframe/test_reduction.py::test_min_max_mean[data0-over_columns_int-skipna_None-numeric_only_None-True-max]
#     86.90415589999793
# modin/pandas/test/dataframe/test_reduction.py::test_min_max_mean[data0-over_columns_str-skipna_None-numeric_only_False-True-max]
#     86.88619999999719
# modin/pandas/test/dataframe/test_reduction.py::test_min_max_mean[data0-over_columns_int-skipna_True-numeric_only_False-True-max]
#     86.65106020000167
# modin/pandas/test/dataframe/test_reduction.py::test_min_max_mean[data0-over_columns_str-skipna_None-numeric_only_False-True-min]
#     86.59852640000099

# %% [markdown]
# Получим для каждого файла тесты, которые в сумме работают меньше 300 секунд

# %%
max_durations = 300
for i in list_files:
    dict_name_duration = pop.get_group_test_with_less_time(f'{path_dir}/{i}', max_durations)
    for name in dict_name_duration:
        print(f'{name}')
    print('\n')
# Out:
# modin/pandas/test/test_general.py::test_empty_dataframe
# modin/pandas/test/test_general.py::test_empty_series
# modin/pandas/test/test_general.py::test_merge
# modin/pandas/test/test_general.py::test_merge_asof_bad_arguments
# modin/pandas/test/test_general.py::test_pivot
# modin/pandas/test/test_general.py::test_to_datetime
# modin/pandas/test/test_general.py::test_to_datetime_inplace_side_effect
# modin/pandas/test/test_general.py::test_to_numeric
#
#
# modin/pandas/test/test_io.py::TestCsv::test_from_csv_with_callable_usecols
# modin/pandas/test/test_io.py::TestCsv::test_read_csv_bad_quotes
# modin/pandas/test/test_io.py::TestCsv::test_read_csv_categories
# modin/pandas/test/test_io.py::TestCsv::test_read_csv_col_handling
# modin/pandas/test/test_io.py::TestCsv::test_read_csv_compression
# modin/pandas/test/test_io.py::TestCsv::test_read_csv_datetime
# modin/pandas/test/test_io.py::TestCsv::test_read_csv_delimiters
# modin/pandas/test/test_io.py::TestCsv::test_read_csv_empty_frame
# modin/pandas/test/test_io.py::TestCsv::test_read_csv_encoding_976
# modin/pandas/test/test_io.py::TestCsv::test_read_csv_error_handling
# modin/pandas/test/test_io.py::TestCsv::test_read_csv_file_format
# modin/pandas/test/test_io.py::TestCsv::test_read_csv_file_handle
# modin/pandas/test/test_io.py::TestCsv::test_read_csv_internal
# modin/pandas/test/test_io.py::TestCsv::test_read_csv_iteration
# modin/pandas/test/test_io.py::TestCsv::test_read_csv_mangle_dupe_cols
# modin/pandas/test/test_io.py::TestCsv::test_read_csv_names_neq_num_cols
# modin/pandas/test/test_io.py::TestCsv::test_read_csv_nans_handling
# modin/pandas/test/test_io.py::TestCsv::test_read_csv_newlines_in_quotes
# modin/pandas/test/test_io.py::TestCsv::test_read_csv_parse_dates
# modin/pandas/test/test_io.py::TestCsv::test_read_csv_parsing_1
# modin/pandas/test/test_io.py::TestCsv::test_read_csv_parsing_2
# modin/pandas/test/test_io.py::TestCsv::test_read_csv_parsing_3
# modin/pandas/test/test_io.py::TestCsv::test_read_csv_quoting
# modin/pandas/test/test_io.py::TestCsv::test_read_csv_s3
# modin/pandas/test/test_io.py::TestCsv::test_read_csv_sep_none
# modin/pandas/test/test_io.py::TestCsv::test_read_csv_skipinitialspace
# modin/pandas/test/test_io.py::TestCsv::test_read_csv_skiprows_names
# modin/pandas/test/test_io.py::TestCsv::test_read_csv_within_decorator
# modin/pandas/test/test_io.py::TestCsv::test_read_csv_wrong_path
# modin/pandas/test/test_io.py::TestCsv::test_unnamed_index
# modin/pandas/test/test_io.py::TestExcel::test_excel_empty_line
# modin/pandas/test/test_io.py::TestExcel::test_read_excel
# modin/pandas/test/test_io.py::TestExcel::test_read_excel_sheet_name
# modin/pandas/test/test_io.py::TestExcel::test_read_excel_sheetname_title
# modin/pandas/test/test_io.py::TestExcel::test_to_excel
# modin/pandas/test/test_io.py::TestFwf::test_fwf_file
# modin/pandas/test/test_io.py::TestFwf::test_fwf_file_chunksize
# modin/pandas/test/test_io.py::TestFwf::test_fwf_file_colspecs_widths
# modin/pandas/test/test_io.py::TestFwf::test_fwf_file_index_col
# modin/pandas/test/test_io.py::TestFwf::test_fwf_file_parse_dates
# modin/pandas/test/test_io.py::TestFwf::test_fwf_file_skipfooter
# modin/pandas/test/test_io.py::TestFwf::test_fwf_file_skiprows
# modin/pandas/test/test_io.py::TestFwf::test_fwf_file_usecols
# modin/pandas/test/test_io.py::TestFwf::test_read_fwf_empty_frame
# modin/pandas/test/test_io.py::TestFwf::test_read_fwf_file_handle
# modin/pandas/test/test_io.py::TestHtml::test_to_html
# modin/pandas/test/test_io.py::TestJson::test_read_json
# modin/pandas/test/test_io.py::TestJson::test_read_json_categories
# modin/pandas/test/test_io.py::TestJson::test_read_json_file_handle
# modin/pandas/test/test_io.py::TestJson::test_to_json
# modin/pandas/test/test_io.py::TestPickle::test_read_pickle
# modin/pandas/test/test_io.py::TestSql::test_to_sql
# modin/pandas/test/test_io.py::TestStata::test_read_stata
# modin/pandas/test/test_io.py::TestStata::test_to_stata
# modin/pandas/test/test_io.py::TestTable::test_read_table
# modin/pandas/test/test_io.py::TestTable::test_read_table_empty_frame
# modin/pandas/test/test_io.py::TestTable::test_read_table_within_decorator
# modin/pandas/test/test_io.py::test_to_dict
# modin/pandas/test/test_io.py::test_to_latex
# modin/pandas/test/test_io.py::test_to_period
#
#
# modin/pandas/test/test_groupby.py::test_internal_by_detection
# modin/pandas/test/test_groupby.py::test_mixed_columns
# modin/pandas/test/test_groupby.py::test_mixed_columns_not_from_df
#
#
# modin/pandas/test/dataframe/test_binary.py::test_duplicate_indexes
# modin/pandas/test/dataframe/test_binary.py::test_equals
# modin/pandas/test/dataframe/test_binary.py::test_math_alias
#
#
# modin/pandas/test/dataframe/test_join_sort.py::test_sort_index
# modin/pandas/test/dataframe/test_join_sort.py::test_sort_values_with_duplicates
# modin/pandas/test/dataframe/test_join_sort.py::test_sort_values_with_string_index
#
#
# modin/pandas/test/dataframe/test_iter.py::test___setattr__
# modin/pandas/test/dataframe/test_iter.py::test_items_iteritems_iterrows
#
#
# modin/pandas/test/dataframe/test_default.py::test_combine_first
# modin/pandas/test/dataframe/test_default.py::test_hasattr_sparse
# modin/pandas/test/dataframe/test_default.py::test_replace
#
#
# modin/pandas/test/dataframe/test_indexing.py::test___setitem__with_mismatched_partitions
# modin/pandas/test/dataframe/test_indexing.py::test_getitem_same_name
# modin/pandas/test/dataframe/test_indexing.py::test_iloc_assignment
# modin/pandas/test/dataframe/test_indexing.py::test_loc_assignment
# modin/pandas/test/dataframe/test_indexing.py::test_loc_iter_assignment
# modin/pandas/test/dataframe/test_indexing.py::test_loc_order
# modin/pandas/test/dataframe/test_indexing.py::test_reindex
# modin/pandas/test/dataframe/test_indexing.py::test_rename_bug
#
#
# modin/pandas/test/dataframe/test_udf.py::test_aggregate_alias
# modin/pandas/test/dataframe/test_udf.py::test_apply_metadata
# modin/pandas/test/dataframe/test_udf.py::test_empty_query
# modin/pandas/test/dataframe/test_udf.py::test_explode_all_partitions
# modin/pandas/test/dataframe/test_udf.py::test_explode_single_partition
# modin/pandas/test/dataframe/test_udf.py::test_query_after_insert
#
#
# modin/pandas/test/dataframe/test_window.py::test_cummin_cummax_int_and_float
# modin/pandas/test/dataframe/test_window.py::test_diff
# modin/pandas/test/dataframe/test_window.py::test_fillna_dict_series
# modin/pandas/test/dataframe/test_window.py::test_fillna_downcast
# modin/pandas/test/dataframe/test_window.py::test_fillna_dtype_conversion
# modin/pandas/test/dataframe/test_window.py::test_median_skew_std_var_rank_sem_specific
# modin/pandas/test/dataframe/test_window.py::test_nlargest
# modin/pandas/test/dataframe/test_window.py::test_nsmallest
#
#
# modin/pandas/test/test_series.py::test___getitem__1383
# modin/pandas/test/test_series.py::test___getitem_edge_cases
# modin/pandas/test/test_series.py::test_accessing_index_element_as_property
# modin/pandas/test/test_series.py::test_casefold
# modin/pandas/test/test_series.py::test_cat_add_categories
# modin/pandas/test/test_series.py::test_cat_as_ordered
# modin/pandas/test/test_series.py::test_cat_as_unordered
# modin/pandas/test/test_series.py::test_cat_ordered
# modin/pandas/test/test_series.py::test_cat_remove_categories
# modin/pandas/test/test_series.py::test_cat_remove_unused_categories
# modin/pandas/test/test_series.py::test_cat_rename_categories
# modin/pandas/test/test_series.py::test_cat_reorder_categories
# modin/pandas/test/test_series.py::test_cat_set_categories
# modin/pandas/test/test_series.py::test_drop_duplicates
# modin/pandas/test/test_series.py::test_duplicated
# modin/pandas/test/test_series.py::test_empty_series
# modin/pandas/test/test_series.py::test_encode
# modin/pandas/test/test_series.py::test_equals
# modin/pandas/test/test_series.py::test_explode
# modin/pandas/test/test_series.py::test_hasattr_sparse
# modin/pandas/test/test_series.py::test_kurtosis_alias
# modin/pandas/test/test_series.py::test_peculiar_callback
# modin/pandas/test/test_series.py::test_prod
# modin/pandas/test/test_series.py::test_product_alias
# modin/pandas/test/test_series.py::test_repeat
# modin/pandas/test/test_series.py::test_replace
# modin/pandas/test/test_series.py::test_str___getitem__
# modin/pandas/test/test_series.py::test_str_capitalize
# modin/pandas/test/test_series.py::test_str_center
# modin/pandas/test/test_series.py::test_str_contains
# modin/pandas/test/test_series.py::test_str_count
# modin/pandas/test/test_series.py::test_str_endswith
# modin/pandas/test/test_series.py::test_str_find
# modin/pandas/test/test_series.py::test_str_findall
# modin/pandas/test/test_series.py::test_str_get
# modin/pandas/test/test_series.py::test_str_index
# modin/pandas/test/test_series.py::test_str_isalnum
# modin/pandas/test/test_series.py::test_str_isalpha
# modin/pandas/test/test_series.py::test_str_isdecimal
# modin/pandas/test/test_series.py::test_str_isdigit
# modin/pandas/test/test_series.py::test_str_islower
# modin/pandas/test/test_series.py::test_str_isnumeric
# modin/pandas/test/test_series.py::test_str_isspace
# modin/pandas/test/test_series.py::test_str_istitle
# modin/pandas/test/test_series.py::test_str_isupper
# modin/pandas/test/test_series.py::test_str_join
# modin/pandas/test/test_series.py::test_str_len
# modin/pandas/test/test_series.py::test_str_ljust
# modin/pandas/test/test_series.py::test_str_lower
# modin/pandas/test/test_series.py::test_str_lstrip
# modin/pandas/test/test_series.py::test_str_match
# modin/pandas/test/test_series.py::test_str_normalize
# modin/pandas/test/test_series.py::test_str_pad
# modin/pandas/test/test_series.py::test_str_partition
# modin/pandas/test/test_series.py::test_str_repeat
# modin/pandas/test/test_series.py::test_str_replace
# modin/pandas/test/test_series.py::test_str_rfind
# modin/pandas/test/test_series.py::test_str_rindex
# modin/pandas/test/test_series.py::test_str_rjust
# modin/pandas/test/test_series.py::test_str_rpartition
# modin/pandas/test/test_series.py::test_str_rstrip
# modin/pandas/test/test_series.py::test_str_slice
# modin/pandas/test/test_series.py::test_str_slice_replace
# modin/pandas/test/test_series.py::test_str_startswith
# modin/pandas/test/test_series.py::test_str_strip
# modin/pandas/test/test_series.py::test_str_swapcase
# modin/pandas/test/test_series.py::test_str_title
# modin/pandas/test/test_series.py::test_str_translate
# modin/pandas/test/test_series.py::test_str_upper
# modin/pandas/test/test_series.py::test_str_wrap
# modin/pandas/test/test_series.py::test_str_zfill
# modin/pandas/test/test_series.py::test_update
# modin/pandas/test/test_series.py::test_view
#
#
#
#
#
#
# modin/pandas/test/test_concat.py::test_concat_series_only
# modin/pandas/test/test_concat.py::test_concat_with_empty_frame
# modin/pandas/test/test_concat.py::test_invalid_axis_errors
#
#
# modin/pandas/test/dataframe/test_map_metadata.py::test_drop_api_equivalence
# modin/pandas/test/dataframe/test_map_metadata.py::test_update
# modin/pandas/test/dataframe/test_reduction.py::test_all_any
# modin/pandas/test/dataframe/test_reduction.py::test_all_any_specific
# modin/pandas/test/dataframe/test_reduction.py::test_count
# modin/pandas/test/dataframe/test_reduction.py::test_count_specific
# modin/pandas/test/dataframe/test_reduction.py::test_describe_dtypes
# modin/pandas/test/dataframe/test_reduction.py::test_reduction_specific
# modin/pandas/test/dataframe/test_reduction.py::test_sum_prod_specific
