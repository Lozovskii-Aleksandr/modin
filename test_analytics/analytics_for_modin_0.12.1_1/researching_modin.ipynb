# %%
path_dir = 'json_analytics_from_test'
number_line = 9

# %%
import os
import sys
import inspect

currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0, parentdir)

# %%
from ParseOutputPytest import ParseOutputPytest
pop = ParseOutputPytest()

# %%
# Get a list of tests in the folder
import os
list_files = tuple(os.walk(path_dir))[0][2]

# %%
# Get for each {test: traceback}
list_dict = []
res = {}
for name_file_test in list_files:
    new_dict = pop.get_dict_name_with_error_text(f'{path_dir}\\{name_file_test}')
    res.update(new_dict)

# %%
len(res)
# Out:
# 7739

# %%
for test in res:
    print(test)
#     if "test_io" in test:
#         print(test)
# Out:
# modin/pandas/test/dataframe/test_default.py::test_ops_defaulting_to_pandas[align-<lambda>]
# modin/pandas/test/dataframe/test_default.py::test_ops_defaulting_to_pandas[expanding-None]
# modin/pandas/test/dataframe/test_default.py::test_ops_defaulting_to_pandas[corrwith-<lambda>]
# modin/pandas/test/dataframe/test_default.py::test_ops_defaulting_to_pandas[ewm-<lambda>]
# modin/pandas/test/dataframe/test_default.py::test_ops_defaulting_to_pandas[from_dict-<lambda>]
# modin/pandas/test/dataframe/test_default.py::test_ops_defaulting_to_pandas[from_records-<lambda>]
# modin/pandas/test/dataframe/test_default.py::test_ops_defaulting_to_pandas[hist-<lambda>]
# modin/pandas/test/dataframe/test_default.py::test_ops_defaulting_to_pandas[infer_objects-None]
# modin/pandas/test/dataframe/test_default.py::test_ops_defaulting_to_pandas[interpolate-None]
# modin/pandas/test/dataframe/test_default.py::test_ops_defaulting_to_pandas[lookup-<lambda>]
# modin/pandas/test/dataframe/test_default.py::test_ops_defaulting_to_pandas[mask-<lambda>]
# modin/pandas/test/dataframe/test_default.py::test_ops_defaulting_to_pandas[pct_change-None]
# modin/pandas/test/dataframe/test_default.py::test_ops_defaulting_to_pandas[to_xarray-None]
# modin/pandas/test/dataframe/test_default.py::test_ops_defaulting_to_pandas[flags-None]
# modin/pandas/test/dataframe/test_default.py::test_ops_defaulting_to_pandas[set_flags-<lambda>]
# modin/pandas/test/dataframe/test_default.py::test_style
# modin/pandas/test/dataframe/test_default.py::test_to_timestamp
# modin/pandas/test/dataframe/test_default.py::test_asfreq
# modin/pandas/test/dataframe/test_default.py::test_at_time
# modin/pandas/test/dataframe/test_default.py::test_between_time
# modin/pandas/test/dataframe/test_default.py::test_corr[1]
# modin/pandas/test/dataframe/test_default.py::test_corr[3]
# modin/pandas/test/dataframe/test_default.py::test_corr[5]
# modin/pandas/test/dataframe/test_default.py::test_cov[1-1]
# modin/pandas/test/dataframe/test_default.py::test_cov[1-3]
# modin/pandas/test/dataframe/test_default.py::test_cov[1-5]
# modin/pandas/test/dataframe/test_default.py::test_cov[2-1]
# modin/pandas/test/dataframe/test_default.py::test_cov[2-3]
# modin/pandas/test/dataframe/test_default.py::test_cov[2-5]
# modin/pandas/test/dataframe/test_default.py::test_cov[4-1]
# modin/pandas/test/dataframe/test_default.py::test_cov[4-3]
# modin/pandas/test/dataframe/test_default.py::test_cov[4-5]
# modin/pandas/test/dataframe/test_default.py::test_first
# modin/pandas/test/dataframe/test_default.py::test_kurt_kurtosis_level[-1]
# modin/pandas/test/dataframe/test_default.py::test_kurt_kurtosis_level[0]
# modin/pandas/test/dataframe/test_default.py::test_kurt_kurtosis_level[1]
# modin/pandas/test/dataframe/test_default.py::test_last
# modin/pandas/test/dataframe/test_default.py::test_mad_level[-1]
# modin/pandas/test/dataframe/test_default.py::test_mad_level[0]
# modin/pandas/test/dataframe/test_default.py::test_mad_level[1]
# modin/pandas/test/dataframe/test_default.py::test_pivot_table_data[<lambda>0-<lambda>0-<lambda>1-int_data]
# modin/pandas/test/dataframe/test_default.py::test_pivot_table_data[<lambda>0-<lambda>1-<lambda>0-int_data]
# modin/pandas/test/dataframe/test_default.py::test_pivot_table_data[<lambda>0-<lambda>1-None-int_data]
# modin/pandas/test/dataframe/test_default.py::test_pivot_table_data[<lambda>0-None-<lambda>1-int_data]
# modin/pandas/test/dataframe/test_default.py::test_pivot_table_data[<lambda>1-<lambda>0-<lambda>1-int_data]
# modin/pandas/test/dataframe/test_default.py::test_pivot_table_data[<lambda>1-<lambda>1-<lambda>0-int_data]
# modin/pandas/test/dataframe/test_default.py::test_pivot_table_data[<lambda>1-<lambda>1-None-int_data]
# modin/pandas/test/dataframe/test_default.py::test_pivot_table_data[<lambda>1-None-<lambda>1-int_data]
# modin/pandas/test/dataframe/test_default.py::test_pivot_table_data[None-<lambda>0-<lambda>1-int_data]
# modin/pandas/test/dataframe/test_default.py::test_pivot_table_data[None-<lambda>1-<lambda>0-int_data]
# modin/pandas/test/dataframe/test_default.py::test_pivot_table_data[None-<lambda>1-<lambda>1-int_data]
# modin/pandas/test/dataframe/test_default.py::test_pivot_table_data[None-<lambda>1-None-int_data]
# modin/pandas/test/dataframe/test_default.py::test_pivot_table_data[None-None-<lambda>1-int_data]
# modin/pandas/test/dataframe/test_default.py::test_pivot_table_margins[Custom name-aggfunc0-<lambda>0-<lambda>0-<lambda>1-int_data]
# modin/pandas/test/dataframe/test_default.py::test_pivot_table_margins[Custom name-aggfunc0-<lambda>0-<lambda>1-<lambda>0-int_data]
# modin/pandas/test/dataframe/test_default.py::test_pivot_table_margins[Custom name-aggfunc0-<lambda>0-<lambda>1-<lambda>1-int_data]
# modin/pandas/test/dataframe/test_default.py::test_pivot_table_margins[Custom name-aggfunc0-<lambda>1-<lambda>0-<lambda>1-int_data]
# modin/pandas/test/dataframe/test_default.py::test_pivot_table_margins[Custom name-aggfunc0-<lambda>1-<lambda>1-<lambda>0-int_data]
# modin/pandas/test/dataframe/test_default.py::test_pivot_table_margins[Custom name-aggfunc0-<lambda>1-<lambda>1-<lambda>1-int_data]
# modin/pandas/test/dataframe/test_default.py::test_pivot_table_margins[Custom name-<lambda>-<lambda>0-<lambda>0-<lambda>0-int_data]
# modin/pandas/test/dataframe/test_default.py::test_pivot_table_margins[Custom name-<lambda>-<lambda>0-<lambda>0-<lambda>1-int_data]
# modin/pandas/test/dataframe/test_default.py::test_pivot_table_margins[Custom name-<lambda>-<lambda>0-<lambda>1-<lambda>0-int_data]
# modin/pandas/test/dataframe/test_default.py::test_pivot_table_margins[Custom name-<lambda>-<lambda>0-<lambda>1-<lambda>1-int_data]
# modin/pandas/test/dataframe/test_default.py::test_pivot_table_margins[Custom name-<lambda>-<lambda>1-<lambda>0-<lambda>0-int_data]
# modin/pandas/test/dataframe/test_default.py::test_pivot_table_margins[Custom name-<lambda>-<lambda>1-<lambda>0-<lambda>1-int_data]
# modin/pandas/test/dataframe/test_default.py::test_pivot_table_margins[Custom name-<lambda>-<lambda>1-<lambda>1-<lambda>0-int_data]
# modin/pandas/test/dataframe/test_default.py::test_pivot_table_margins[Custom name-<lambda>-<lambda>1-<lambda>1-<lambda>1-int_data]
# modin/pandas/test/dataframe/test_default.py::test_pivot_table_margins[None-aggfunc0-<lambda>0-<lambda>0-<lambda>1-int_data]
# modin/pandas/test/dataframe/test_default.py::test_pivot_table_margins[None-aggfunc0-<lambda>0-<lambda>1-<lambda>0-int_data]
# modin/pandas/test/dataframe/test_default.py::test_pivot_table_margins[None-aggfunc0-<lambda>0-<lambda>1-<lambda>1-int_data]
# modin/pandas/test/dataframe/test_default.py::test_pivot_table_margins[None-aggfunc0-<lambda>1-<lambda>0-<lambda>1-int_data]
# modin/pandas/test/dataframe/test_default.py::test_pivot_table_margins[None-aggfunc0-<lambda>1-<lambda>1-<lambda>0-int_data]
# modin/pandas/test/dataframe/test_default.py::test_pivot_table_margins[None-aggfunc0-<lambda>1-<lambda>1-<lambda>1-int_data]
# modin/pandas/test/dataframe/test_default.py::test_pivot_table_margins[None-<lambda>-<lambda>0-<lambda>0-<lambda>0-int_data]
# modin/pandas/test/dataframe/test_default.py::test_pivot_table_margins[None-<lambda>-<lambda>0-<lambda>0-<lambda>1-int_data]
# modin/pandas/test/dataframe/test_default.py::test_pivot_table_margins[None-<lambda>-<lambda>0-<lambda>1-<lambda>0-int_data]
# modin/pandas/test/dataframe/test_default.py::test_pivot_table_margins[None-<lambda>-<lambda>0-<lambda>1-<lambda>1-int_data]
# modin/pandas/test/dataframe/test_default.py::test_pivot_table_margins[None-<lambda>-<lambda>1-<lambda>0-<lambda>0-int_data]
# modin/pandas/test/dataframe/test_default.py::test_pivot_table_margins[None-<lambda>-<lambda>1-<lambda>0-<lambda>1-int_data]
# modin/pandas/test/dataframe/test_default.py::test_pivot_table_margins[None-<lambda>-<lambda>1-<lambda>1-<lambda>0-int_data]
# modin/pandas/test/dataframe/test_default.py::test_pivot_table_margins[None-<lambda>-<lambda>1-<lambda>1-<lambda>1-int_data]
# modin/pandas/test/dataframe/test_default.py::test_plot[int_data]
# modin/pandas/test/dataframe/test_default.py::test_plot[float_nan_data]
# modin/pandas/test/dataframe/test_default.py::test_resampler[0-5T]
# modin/pandas/test/dataframe/test_default.py::test_resampler[0-rule1]
# modin/pandas/test/dataframe/test_default.py::test_resampler_functions[count-index-5T]
# modin/pandas/test/dataframe/test_default.py::test_resampler_functions[sum-index-5T]
# modin/pandas/test/dataframe/test_default.py::test_resampler_functions[std-index-5T]
# modin/pandas/test/dataframe/test_default.py::test_resampler_functions[sem-index-5T]
# modin/pandas/test/dataframe/test_default.py::test_resampler_functions[size-index-5T]
# modin/pandas/test/dataframe/test_default.py::test_resampler_functions[prod-index-5T]
# modin/pandas/test/dataframe/test_default.py::test_resampler_functions[ohlc-index-5T]
# modin/pandas/test/dataframe/test_default.py::test_resampler_functions[quantile-index-5T]
# modin/pandas/test/dataframe/test_default.py::test_resampler_functions[min-index-5T]
# modin/pandas/test/dataframe/test_default.py::test_resampler_functions[median-index-5T]
# modin/pandas/test/dataframe/test_default.py::test_resampler_functions[mean-index-5T]
# modin/pandas/test/dataframe/test_default.py::test_resampler_functions[max-index-5T]
# modin/pandas/test/dataframe/test_default.py::test_resampler_functions[last-index-5T]
# modin/pandas/test/dataframe/test_default.py::test_resampler_functions[first-index-5T]
# modin/pandas/test/dataframe/test_default.py::test_resampler_functions[nunique-index-5T]
# modin/pandas/test/dataframe/test_default.py::test_resampler_functions[var-index-5T]
# modin/pandas/test/dataframe/test_default.py::test_resampler_functions[interpolate-index-5T]
# modin/pandas/test/dataframe/test_default.py::test_resampler_functions[asfreq-index-5T]
# modin/pandas/test/dataframe/test_default.py::test_resampler_functions[pad-index-5T]
# modin/pandas/test/dataframe/test_default.py::test_resampler_functions[nearest-index-5T]
# modin/pandas/test/dataframe/test_default.py::test_resampler_functions[bfill-index-5T]
# modin/pandas/test/dataframe/test_default.py::test_resampler_functions[backfill-index-5T]
# modin/pandas/test/dataframe/test_default.py::test_resampler_functions[ffill-index-5T]
# modin/pandas/test/dataframe/test_default.py::test_resampler_functions_with_arg[method_arg0-index-5T]
# modin/pandas/test/dataframe/test_default.py::test_resampler_functions_with_arg[method_arg1-index-5T]
# modin/pandas/test/dataframe/test_default.py::test_resampler_functions_with_arg[method_arg2-index-5T]
# modin/pandas/test/dataframe/test_default.py::test_resampler_functions_with_arg[method_arg3-index-5T]
# modin/pandas/test/dataframe/test_default.py::test_resample_specific[None-None-right-left-5T]
# modin/pandas/test/dataframe/test_default.py::test_resample_specific[None-None-right-right-5T]
# modin/pandas/test/dataframe/test_default.py::test_resample_specific[None-None-left-left-5T]
# modin/pandas/test/dataframe/test_default.py::test_resample_specific[None-None-left-right-5T]
# modin/pandas/test/dataframe/test_default.py::test_resample_specific[None-DateColumn-right-left-5T]
# modin/pandas/test/dataframe/test_default.py::test_resample_specific[None-DateColumn-right-right-5T]
# modin/pandas/test/dataframe/test_default.py::test_resample_specific[None-DateColumn-left-left-5T]
# modin/pandas/test/dataframe/test_default.py::test_resample_specific[None-DateColumn-left-right-5T]
# modin/pandas/test/dataframe/test_default.py::test_resample_specific[1-None-right-left-5T]
# modin/pandas/test/dataframe/test_default.py::test_resample_specific[1-None-right-right-5T]
# modin/pandas/test/dataframe/test_default.py::test_resample_specific[1-None-left-left-5T]
# modin/pandas/test/dataframe/test_default.py::test_resample_specific[1-None-left-right-5T]
# modin/pandas/test/dataframe/test_default.py::test_resample_specific[1-DateColumn-right-left-5T]
# modin/pandas/test/dataframe/test_default.py::test_resample_specific[1-DateColumn-right-right-5T]
# modin/pandas/test/dataframe/test_default.py::test_resample_specific[1-DateColumn-left-left-5T]
# modin/pandas/test/dataframe/test_default.py::test_resample_specific[1-DateColumn-left-right-5T]
# modin/pandas/test/dataframe/test_default.py::test_resample_getitem[column]
# modin/pandas/test/dataframe/test_default.py::test_resample_getitem[list]
# modin/pandas/test/dataframe/test_default.py::test_resample_getitem[tuple]
# modin/pandas/test/dataframe/test_default.py::test_resample_getitem[series]
# modin/pandas/test/dataframe/test_default.py::test_resample_getitem[index]
# modin/pandas/test/dataframe/test_default.py::test_shift_slice_shift[0-0-ndarray-int_data]
# modin/pandas/test/dataframe/test_default.py::test_shift_slice_shift[0-0-ndarray-float_nan_data]
# modin/pandas/test/dataframe/test_default.py::test_shift_slice_shift[0-1-ndarray-int_data]
# modin/pandas/test/dataframe/test_default.py::test_shift_slice_shift[0-1-ndarray-float_nan_data]
# modin/pandas/test/dataframe/test_default.py::test_shift_slice_shift[1-0-ndarray-int_data]
# modin/pandas/test/dataframe/test_default.py::test_shift_slice_shift[1-0-ndarray-float_nan_data]
# modin/pandas/test/dataframe/test_default.py::test_shift_slice_shift[1-1-ndarray-int_data]
# modin/pandas/test/dataframe/test_default.py::test_shift_slice_shift[1-1-ndarray-float_nan_data]
# modin/pandas/test/dataframe/test_default.py::test_shift_slice_shift[-1-0-ndarray-int_data]
# modin/pandas/test/dataframe/test_default.py::test_shift_slice_shift[-1-0-ndarray-float_nan_data]
# modin/pandas/test/dataframe/test_default.py::test_shift_slice_shift[-1-1-ndarray-int_data]
# modin/pandas/test/dataframe/test_default.py::test_shift_slice_shift[-1-1-ndarray-float_nan_data]
# modin/pandas/test/dataframe/test_default.py::test_shift_slice_shift[10-0-ndarray-int_data]
# modin/pandas/test/dataframe/test_default.py::test_shift_slice_shift[10-0-ndarray-float_nan_data]
# modin/pandas/test/dataframe/test_default.py::test_shift_slice_shift[10-1-ndarray-int_data]
# modin/pandas/test/dataframe/test_default.py::test_shift_slice_shift[10-1-ndarray-float_nan_data]
# modin/pandas/test/dataframe/test_default.py::test_shift_slice_shift[-10-0-ndarray-int_data]
# modin/pandas/test/dataframe/test_default.py::test_shift_slice_shift[-10-0-ndarray-float_nan_data]
# modin/pandas/test/dataframe/test_default.py::test_shift_slice_shift[-10-1-ndarray-int_data]
# modin/pandas/test/dataframe/test_default.py::test_shift_slice_shift[-10-1-ndarray-float_nan_data]
# modin/pandas/test/dataframe/test_default.py::test_shift_slice_shift[1000000000-0-default-int_data]
# modin/pandas/test/dataframe/test_default.py::test_shift_slice_shift[1000000000-0-default-float_nan_data]
# modin/pandas/test/dataframe/test_default.py::test_shift_slice_shift[1000000000-0-ndarray-int_data]
# modin/pandas/test/dataframe/test_default.py::test_shift_slice_shift[1000000000-0-ndarray-float_nan_data]
# modin/pandas/test/dataframe/test_default.py::test_shift_slice_shift[1000000000-0-has_duplicates-int_data]
# modin/pandas/test/dataframe/test_default.py::test_shift_slice_shift[1000000000-0-has_duplicates-float_nan_data]
# modin/pandas/test/dataframe/test_default.py::test_shift_slice_shift[1000000000-1-ndarray-int_data]
# modin/pandas/test/dataframe/test_default.py::test_shift_slice_shift[1000000000-1-ndarray-float_nan_data]
# modin/pandas/test/dataframe/test_default.py::test_shift_slice_shift[-1000000000-0-default-int_data]
# modin/pandas/test/dataframe/test_default.py::test_shift_slice_shift[-1000000000-0-default-float_nan_data]
# modin/pandas/test/dataframe/test_default.py::test_shift_slice_shift[-1000000000-0-ndarray-int_data]
# modin/pandas/test/dataframe/test_default.py::test_shift_slice_shift[-1000000000-0-ndarray-float_nan_data]
# modin/pandas/test/dataframe/test_default.py::test_shift_slice_shift[-1000000000-0-has_duplicates-int_data]
# modin/pandas/test/dataframe/test_default.py::test_shift_slice_shift[-1000000000-0-has_duplicates-float_nan_data]
# modin/pandas/test/dataframe/test_default.py::test_shift_slice_shift[-1000000000-1-ndarray-int_data]
# modin/pandas/test/dataframe/test_default.py::test_shift_slice_shift[-1000000000-1-ndarray-float_nan_data]
# modin/pandas/test/dataframe/test_default.py::test_stack[int_data-col_multi-idx_multi]
# modin/pandas/test/dataframe/test_default.py::test_stack[int_data-col_multi-idx_index]
# modin/pandas/test/dataframe/test_default.py::test_stack[int_data-col_index-idx_multi]
# modin/pandas/test/dataframe/test_default.py::test_stack[int_data-col_index-idx_index]
# modin/pandas/test/dataframe/test_default.py::test_stack[float_nan_data-col_multi-idx_multi]
# modin/pandas/test/dataframe/test_default.py::test_stack[float_nan_data-col_multi-idx_index]
# modin/pandas/test/dataframe/test_default.py::test_stack[float_nan_data-col_index-idx_multi]
# modin/pandas/test/dataframe/test_default.py::test_stack[float_nan_data-col_index-idx_index]
# modin/pandas/test/dataframe/test_default.py::test_swaplevel
# modin/pandas/test/dataframe/test_default.py::test_take
# modin/pandas/test/dataframe/test_default.py::test_tshift
# modin/pandas/test/dataframe/test_default.py::test_tz_convert
# modin/pandas/test/dataframe/test_default.py::test_tz_localize
# modin/pandas/test/dataframe/test_default.py::test_unstack[int_data-col_multi-idx_multi]
# modin/pandas/test/dataframe/test_default.py::test_unstack[int_data-col_multi-idx_index]
# modin/pandas/test/dataframe/test_default.py::test_unstack[int_data-col_index-idx_multi]
# modin/pandas/test/dataframe/test_default.py::test_unstack[int_data-col_index-idx_index]
# modin/pandas/test/dataframe/test_default.py::test_unstack[float_nan_data-col_multi-idx_multi]
# modin/pandas/test/dataframe/test_default.py::test_unstack[float_nan_data-col_multi-idx_index]
# modin/pandas/test/dataframe/test_default.py::test_unstack[float_nan_data-col_index-idx_multi]
# modin/pandas/test/dataframe/test_default.py::test_unstack[float_nan_data-col_index-idx_index]
# modin/pandas/test/dataframe/test_default.py::test_unstack_multiindex_types[idx_multi_tree-col_multi_tree]
# modin/pandas/test/dataframe/test_default.py::test_unstack_multiindex_types[idx_multi_tree-col_multi_not_tree]
# modin/pandas/test/dataframe/test_default.py::test_unstack_multiindex_types[idx_multi_tree-col_index]
# modin/pandas/test/dataframe/test_default.py::test_unstack_multiindex_types[idx_multi_not_tree-col_multi_tree]
# modin/pandas/test/dataframe/test_default.py::test_unstack_multiindex_types[idx_multi_not_tree-col_multi_not_tree]
# modin/pandas/test/dataframe/test_default.py::test_unstack_multiindex_types[idx_multi_not_tree-col_index]
# modin/pandas/test/dataframe/test_default.py::test_unstack_multiindex_types[idx_index-col_multi_tree]
# modin/pandas/test/dataframe/test_default.py::test_unstack_multiindex_types[idx_index-col_multi_not_tree]
# modin/pandas/test/dataframe/test_default.py::test_unstack_multiindex_types[idx_index-col_index]
# modin/pandas/test/dataframe/test_binary.py::test_math_functions_level[add]
# modin/pandas/test/dataframe/test_binary.py::test_math_functions_level[radd]
# modin/pandas/test/dataframe/test_binary.py::test_math_functions_level[sub]
# modin/pandas/test/dataframe/test_binary.py::test_math_functions_level[rsub]
# modin/pandas/test/dataframe/test_binary.py::test_math_functions_level[mod]
# modin/pandas/test/dataframe/test_binary.py::test_math_functions_level[rmod]
# modin/pandas/test/dataframe/test_binary.py::test_math_functions_level[pow]
# modin/pandas/test/dataframe/test_binary.py::test_math_functions_level[rpow]
# modin/pandas/test/dataframe/test_binary.py::test_math_functions_level[truediv]
# modin/pandas/test/dataframe/test_binary.py::test_math_functions_level[rtruediv]
# modin/pandas/test/dataframe/test_binary.py::test_math_functions_level[mul]
# modin/pandas/test/dataframe/test_binary.py::test_math_functions_level[rmul]
# modin/pandas/test/dataframe/test_binary.py::test_math_functions_level[floordiv]
# modin/pandas/test/dataframe/test_binary.py::test_math_functions_level[rfloordiv]
# modin/pandas/test/dataframe/test_binary.py::test_multi_level_comparison[int_data-eq]
# modin/pandas/test/dataframe/test_binary.py::test_multi_level_comparison[int_data-ge]
# modin/pandas/test/dataframe/test_binary.py::test_multi_level_comparison[int_data-gt]
# modin/pandas/test/dataframe/test_binary.py::test_multi_level_comparison[int_data-le]
# modin/pandas/test/dataframe/test_binary.py::test_multi_level_comparison[int_data-lt]
# modin/pandas/test/dataframe/test_binary.py::test_multi_level_comparison[int_data-ne]
# modin/pandas/test/dataframe/test_binary.py::test_multi_level_comparison[float_nan_data-eq]
# modin/pandas/test/dataframe/test_binary.py::test_multi_level_comparison[float_nan_data-ge]
# modin/pandas/test/dataframe/test_binary.py::test_multi_level_comparison[float_nan_data-gt]
# modin/pandas/test/dataframe/test_binary.py::test_multi_level_comparison[float_nan_data-le]
# modin/pandas/test/dataframe/test_binary.py::test_multi_level_comparison[float_nan_data-lt]
# modin/pandas/test/dataframe/test_binary.py::test_multi_level_comparison[float_nan_data-ne]
# modin/pandas/test/dataframe/test_binary.py::test_mismatched_row_partitions[idx_aligned-df_ser-True]
# modin/pandas/test/dataframe/test_binary.py::test_mismatched_row_partitions[idx_aligned-df_ser-False]
# modin/pandas/test/dataframe/test_binary.py::test_mismatched_row_partitions[idx_aligned-df_df-True]
# modin/pandas/test/dataframe/test_binary.py::test_mismatched_row_partitions[idx_aligned-df_df-False]
# modin/pandas/test/dataframe/test_binary.py::test_mismatched_row_partitions[idx_aligned-ser_ser_same_name-True]
# modin/pandas/test/dataframe/test_binary.py::test_mismatched_row_partitions[idx_aligned-ser_ser_same_name-False]
# modin/pandas/test/dataframe/test_binary.py::test_mismatched_row_partitions[idx_aligned-ser_ser_different_name-True]
# modin/pandas/test/dataframe/test_binary.py::test_mismatched_row_partitions[idx_aligned-ser_ser_different_name-False]
# modin/pandas/test/dataframe/test_indexing.py::test_asof_with_nan[a-dates0]
# modin/pandas/test/dataframe/test_indexing.py::test_asof_with_nan[a-dates1]
# modin/pandas/test/dataframe/test_indexing.py::test_asof_with_nan[b-dates0]
# modin/pandas/test/dataframe/test_indexing.py::test_asof_with_nan[b-dates1]
# modin/pandas/test/dataframe/test_indexing.py::test_asof_with_nan[subset2-dates0]
# modin/pandas/test/dataframe/test_indexing.py::test_asof_with_nan[subset2-dates1]
# modin/pandas/test/dataframe/test_indexing.py::test_asof_with_nan[None-dates0]
# modin/pandas/test/dataframe/test_indexing.py::test_asof_with_nan[None-dates1]
# modin/pandas/test/dataframe/test_indexing.py::test_asof_without_nan[a-dates0]
# modin/pandas/test/dataframe/test_indexing.py::test_asof_without_nan[a-dates1]
# modin/pandas/test/dataframe/test_indexing.py::test_asof_without_nan[b-dates0]
# modin/pandas/test/dataframe/test_indexing.py::test_asof_without_nan[b-dates1]
# modin/pandas/test/dataframe/test_indexing.py::test_asof_without_nan[subset2-dates0]
# modin/pandas/test/dataframe/test_indexing.py::test_asof_without_nan[subset2-dates1]
# modin/pandas/test/dataframe/test_indexing.py::test_asof_without_nan[None-dates0]
# modin/pandas/test/dataframe/test_indexing.py::test_asof_without_nan[None-dates1]
# modin/pandas/test/dataframe/test_indexing.py::test_asof_large[col2-lookup0]
# modin/pandas/test/dataframe/test_indexing.py::test_asof_large[col2-lookup1]
# modin/pandas/test/dataframe/test_indexing.py::test_asof_large[col1-lookup0]
# modin/pandas/test/dataframe/test_indexing.py::test_asof_large[col1-lookup1]
# modin/pandas/test/dataframe/test_indexing.py::test_asof_large[subset2-lookup0]
# modin/pandas/test/dataframe/test_indexing.py::test_asof_large[subset2-lookup1]
# modin/pandas/test/dataframe/test_indexing.py::test_asof_large[None-lookup0]
# modin/pandas/test/dataframe/test_indexing.py::test_asof_large[None-lookup1]
# modin/pandas/test/dataframe/test_indexing.py::test_head[n_0-int_data]
# modin/pandas/test/dataframe/test_indexing.py::test_head[n_0-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_iloc[int_data]
# modin/pandas/test/dataframe/test_indexing.py::test_iloc[float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_loc[int_data]
# modin/pandas/test/dataframe/test_indexing.py::test_loc[float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_loc_multi_index
# modin/pandas/test/dataframe/test_indexing.py::test_loc_nested_assignment[int_data]
# modin/pandas/test/dataframe/test_indexing.py::test_loc_nested_assignment[float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_iloc_nested_assignment[int_data]
# modin/pandas/test/dataframe/test_indexing.py::test_iloc_nested_assignment[float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_loc_series
# modin/pandas/test/dataframe/test_indexing.py::test_loc_iloc_slice_indexer[slice_indexer0-loc]
# modin/pandas/test/dataframe/test_indexing.py::test_loc_iloc_slice_indexer[slice_indexer0-iloc]
# modin/pandas/test/dataframe/test_indexing.py::test_loc_iloc_slice_indexer[slice_indexer1-loc]
# modin/pandas/test/dataframe/test_indexing.py::test_loc_iloc_slice_indexer[slice_indexer1-iloc]
# modin/pandas/test/dataframe/test_indexing.py::test_loc_iloc_slice_indexer[slice_indexer2-loc]
# modin/pandas/test/dataframe/test_indexing.py::test_loc_iloc_slice_indexer[slice_indexer2-iloc]
# modin/pandas/test/dataframe/test_indexing.py::test_loc_iloc_slice_indexer[slice_indexer3-loc]
# modin/pandas/test/dataframe/test_indexing.py::test_loc_iloc_slice_indexer[slice_indexer3-iloc]
# modin/pandas/test/dataframe/test_indexing.py::test_loc_iloc_slice_indexer[slice_indexer4-loc]
# modin/pandas/test/dataframe/test_indexing.py::test_loc_iloc_slice_indexer[slice_indexer4-iloc]
# modin/pandas/test/dataframe/test_indexing.py::test_loc_iloc_slice_indexer[slice_indexer5-loc]
# modin/pandas/test/dataframe/test_indexing.py::test_loc_iloc_slice_indexer[slice_indexer5-iloc]
# modin/pandas/test/dataframe/test_indexing.py::test_loc_iloc_slice_indexer[slice_indexer6-loc]
# modin/pandas/test/dataframe/test_indexing.py::test_loc_iloc_slice_indexer[slice_indexer6-iloc]
# modin/pandas/test/dataframe/test_indexing.py::test_pop[int_data]
# modin/pandas/test/dataframe/test_indexing.py::test_pop[float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reindex_like
# modin/pandas/test/dataframe/test_indexing.py::test_rename_sanity
# modin/pandas/test/dataframe/test_indexing.py::test_rename_multiindex
# modin/pandas/test/dataframe/test_indexing.py::test_rename_inplace
# modin/pandas/test/dataframe/test_indexing.py::test_rename_axis
# modin/pandas/test/dataframe/test_indexing.py::test_rename_axis_inplace
# modin/pandas/test/dataframe/test_indexing.py::test_reorder_levels
# modin/pandas/test/dataframe/test_indexing.py::test_reindex_multiindex
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index[int_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index[float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-no_col_level-no_level-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-no_col_level-no_level-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-no_col_level-None-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-no_col_level-None-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-no_col_level-0-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-no_col_level-0-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-no_col_level-1-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-no_col_level-1-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-no_col_level-2-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-no_col_level-2-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-no_col_level-level5-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-no_col_level-level5-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-no_col_level-level6-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-no_col_level-level6-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-no_col_level-level7-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-no_col_level-level7-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-0-no_level-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-0-no_level-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-0-None-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-0-None-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-0-0-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-0-0-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-0-1-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-0-1-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-0-2-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-0-2-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-0-level5-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-0-level5-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-0-level6-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-0-level6-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-0-level7-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-0-level7-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-1-no_level-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-1-no_level-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-1-None-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-1-None-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-1-0-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-1-0-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-1-1-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-1-1-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-1-2-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-1-2-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-1-level5-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-1-level5-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-1-level6-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-1-level6-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-1-level7-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-1-level7-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-2-no_level-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-2-no_level-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-2-None-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-2-None-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-2-0-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-2-0-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-2-1-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-2-1-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-2-2-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-2-2-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-2-level5-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-2-level5-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-2-level6-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-2-level6-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-2-level7-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-no_col_fill-2-level7-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-no_col_level-no_level-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-no_col_level-no_level-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-no_col_level-None-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-no_col_level-None-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-no_col_level-0-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-no_col_level-0-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-no_col_level-1-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-no_col_level-1-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-no_col_level-2-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-no_col_level-2-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-no_col_level-level5-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-no_col_level-level5-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-no_col_level-level6-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-no_col_level-level6-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-no_col_level-level7-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-no_col_level-level7-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-0-no_level-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-0-no_level-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-0-None-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-0-None-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-0-0-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-0-0-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-0-1-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-0-1-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-0-2-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-0-2-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-0-level5-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-0-level5-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-0-level6-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-0-level6-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-0-level7-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-0-level7-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-1-no_level-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-1-no_level-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-1-None-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-1-None-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-1-0-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-1-0-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-1-1-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-1-1-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-1-2-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-1-2-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-1-level5-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-1-level5-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-1-level6-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-1-level6-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-1-level7-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-1-level7-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-2-no_level-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-2-no_level-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-2-None-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-2-None-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-2-0-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-2-0-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-2-1-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-2-1-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-2-2-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-2-2-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-2-level5-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-2-level5-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-2-level6-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-2-level6-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-2-level7-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-None-2-level7-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-0-no_col_level-no_level-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-0-no_col_level-no_level-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-0-no_col_level-None-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-0-no_col_level-None-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-0-no_col_level-0-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-0-no_col_level-0-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-0-no_col_level-1-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-0-no_col_level-1-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-0-no_col_level-2-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-0-no_col_level-2-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-0-no_col_level-level5-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-0-no_col_level-level5-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-0-no_col_level-level6-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-0-no_col_level-level6-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-0-no_col_level-level7-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-0-no_col_level-level7-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-0-0-no_level-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-0-0-no_level-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-0-0-None-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-0-0-None-False-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-0-0-0-True-3-float_nan_data]
# modin/pandas/test/dataframe/test_indexing.py::test_reset_index_with_multi_index_no_drop[True-0-False-0-0-0-False-3-float_nan_data]
# ...
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-modin_dtypes_impl-False-2-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-modin_dtypes_impl-False-2-2]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-apply_sum-True-0-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-apply_sum-True-0-2]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-apply_sum-True-1-0]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-apply_sum-True-1-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-apply_sum-True-1-2]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-apply_sum-True-2-0]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-apply_sum-True-2-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-apply_sum-True-2-2]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-apply_sum-False-0-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-apply_sum-False-0-2]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-apply_sum-False-1-0]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-apply_sum-False-1-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-apply_sum-False-1-2]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-apply_sum-False-2-0]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-apply_sum-False-2-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-apply_sum-False-2-2]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-count-True-0-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-count-True-0-2]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-count-True-1-0]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-count-True-1-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-count-True-1-2]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-count-True-2-0]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-count-True-2-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-count-True-2-2]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-count-False-0-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-count-False-0-2]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-count-False-1-0]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-count-False-1-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-count-False-1-2]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-count-False-2-0]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-count-False-2-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-count-False-2-2]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-nunique-True-0-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-nunique-True-1-0]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-nunique-False-0-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-nunique-False-0-2]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-nunique-False-1-0]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-nunique-False-1-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-nunique-False-1-2]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-nunique-False-2-0]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-nunique-False-2-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-nunique-False-2-2]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-dict_agg_no_intersection_with_by-True-0-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-dict_agg_no_intersection_with_by-True-1-0]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-dict_agg_no_intersection_with_by-False-0-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-dict_agg_no_intersection_with_by-False-0-2]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-dict_agg_no_intersection_with_by-False-1-0]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-dict_agg_no_intersection_with_by-False-1-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-dict_agg_no_intersection_with_by-False-1-2]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-dict_agg_no_intersection_with_by-False-2-0]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-dict_agg_no_intersection_with_by-False-2-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-dict_agg_no_intersection_with_by-False-2-2]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-dict_agg_has_intersection_with_by-True-0-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-dict_agg_has_intersection_with_by-True-1-0]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-dict_agg_has_intersection_with_by-False-0-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-dict_agg_has_intersection_with_by-False-0-2]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-dict_agg_has_intersection_with_by-False-1-0]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-dict_agg_has_intersection_with_by-False-1-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-dict_agg_has_intersection_with_by-False-1-2]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-dict_agg_has_intersection_with_by-False-2-0]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-dict_agg_has_intersection_with_by-False-2-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-dict_agg_has_intersection_with_by-False-2-2]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-dict_agg_has_intersection_with_categorical_by-True-0-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-dict_agg_has_intersection_with_categorical_by-True-1-0]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-dict_agg_has_intersection_with_categorical_by-False-0-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-dict_agg_has_intersection_with_categorical_by-False-0-2]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-dict_agg_has_intersection_with_categorical_by-False-1-0]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-dict_agg_has_intersection_with_categorical_by-False-1-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-dict_agg_has_intersection_with_categorical_by-False-1-2]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-dict_agg_has_intersection_with_categorical_by-False-2-0]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-dict_agg_has_intersection_with_categorical_by-False-2-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[True-dict_agg_has_intersection_with_categorical_by-False-2-2]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-modin_dtypes_impl-True-0-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-modin_dtypes_impl-True-0-2]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-modin_dtypes_impl-True-1-0]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-modin_dtypes_impl-True-1-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-modin_dtypes_impl-True-1-2]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-modin_dtypes_impl-True-2-0]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-modin_dtypes_impl-True-2-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-modin_dtypes_impl-True-2-2]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-modin_dtypes_impl-False-0-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-modin_dtypes_impl-False-0-2]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-modin_dtypes_impl-False-1-0]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-modin_dtypes_impl-False-1-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-modin_dtypes_impl-False-1-2]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-modin_dtypes_impl-False-2-0]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-modin_dtypes_impl-False-2-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-modin_dtypes_impl-False-2-2]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-apply_sum-True-0-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-apply_sum-True-0-2]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-apply_sum-True-1-0]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-apply_sum-True-1-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-apply_sum-True-1-2]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-apply_sum-True-2-0]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-apply_sum-True-2-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-apply_sum-True-2-2]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-apply_sum-False-0-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-apply_sum-False-0-2]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-apply_sum-False-1-0]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-apply_sum-False-1-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-apply_sum-False-1-2]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-apply_sum-False-2-0]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-apply_sum-False-2-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-apply_sum-False-2-2]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-count-True-0-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-count-True-0-2]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-count-True-1-0]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-count-True-1-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-count-True-1-2]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-count-True-2-0]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-count-True-2-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-count-True-2-2]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-count-False-0-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-count-False-0-2]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-count-False-1-0]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-count-False-1-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-count-False-1-2]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-count-False-2-0]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-count-False-2-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-count-False-2-2]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-nunique-True-0-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-nunique-True-1-0]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-nunique-False-0-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-nunique-False-0-2]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-nunique-False-1-0]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-nunique-False-1-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-nunique-False-1-2]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-nunique-False-2-0]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-nunique-False-2-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-nunique-False-2-2]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-dict_agg_no_intersection_with_by-True-0-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-dict_agg_no_intersection_with_by-True-1-0]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-dict_agg_no_intersection_with_by-False-0-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-dict_agg_no_intersection_with_by-False-0-2]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-dict_agg_no_intersection_with_by-False-1-0]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-dict_agg_no_intersection_with_by-False-1-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-dict_agg_no_intersection_with_by-False-1-2]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-dict_agg_no_intersection_with_by-False-2-0]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-dict_agg_no_intersection_with_by-False-2-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-dict_agg_no_intersection_with_by-False-2-2]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-dict_agg_has_intersection_with_by-True-0-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-dict_agg_has_intersection_with_by-True-1-0]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-dict_agg_has_intersection_with_by-False-0-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-dict_agg_has_intersection_with_by-False-0-2]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-dict_agg_has_intersection_with_by-False-1-0]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-dict_agg_has_intersection_with_by-False-1-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-dict_agg_has_intersection_with_by-False-1-2]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-dict_agg_has_intersection_with_by-False-2-0]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-dict_agg_has_intersection_with_by-False-2-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-dict_agg_has_intersection_with_by-False-2-2]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-dict_agg_has_intersection_with_categorical_by-True-0-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-dict_agg_has_intersection_with_categorical_by-True-1-0]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-dict_agg_has_intersection_with_categorical_by-False-0-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-dict_agg_has_intersection_with_categorical_by-False-0-2]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-dict_agg_has_intersection_with_categorical_by-False-1-0]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-dict_agg_has_intersection_with_categorical_by-False-1-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-dict_agg_has_intersection_with_categorical_by-False-1-2]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-dict_agg_has_intersection_with_categorical_by-False-2-0]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-dict_agg_has_intersection_with_categorical_by-False-2-1]
# modin/pandas/test/test_groupby.py::test_handle_as_index[False-dict_agg_has_intersection_with_categorical_by-False-2-2]
# modin/pandas/test/test_groupby.py::test_groupby_sort[True-True]
# modin/pandas/test/test_groupby.py::test_groupby_sort[True-False]
# modin/pandas/test/test_groupby.py::test_groupby_sort[False-True]
# modin/pandas/test/test_groupby.py::test_groupby_sort[False-False]
# modin/pandas/test/test_groupby.py::test_sum_with_level
# modin/pandas/test/test_reshape.py::test_get_dummies
# modin/pandas/test/test_reshape.py::test_melt
# modin/pandas/test/test_reshape.py::test_lreshape
# modin/pandas/test/test_reshape.py::test_wide_to_long
# modin/pandas/test/test_general.py::test_merge_ordered
# modin/pandas/test/test_general.py::test_merge_asof
# modin/pandas/test/test_general.py::test_merge_asof_on_variations
# modin/pandas/test/test_general.py::test_merge_asof_suffixes
# modin/pandas/test/test_general.py::test_merge_asof_merge_options
# modin/pandas/test/test_general.py::test_pivot_table
# modin/pandas/test/test_general.py::test_value_counts[True-3-False]
# modin/pandas/test/test_general.py::test_to_pandas_indices[test_data_values[0]]

# %%
test = 'modin/pandas/test/dataframe/test_join_sort.py::test_sort_values[rotate_decimal_digits_or_symbols-ignore_index_None-first-quicksort-inplace_None-ascending_True-over_rows_str-multiindex_level0-float_nan_data]'
print(res[test])
# Out:
# modin\pandas\test\dataframe\test_join_sort.py:459: in test_sort_values
#     modin_df = pd.DataFrame(data, index=index, columns=columns)
# modin\experimental\cloud\meta_magic.py:155: in __new__
#     return cls.__real_cls__(*a, **kw)
# modin\experimental\cloud\rpyc_proxy.py:438: in __init__
#     __remote_end__ = remote_cls(*a, **kw)
# C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\rpyc\core\netref.py:254: in __call__
#     return syncreq(_self, consts.HANDLE_CALL, args, kwargs)
# C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\rpyc\core\netref.py:76: in syncreq
#     return conn.sync_request(handler, proxy, *args)
# modin\experimental\cloud\rpyc_proxy.py:165: in sync_request
#     return super().sync_request(handler, *args)
# C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\rpyc\core\protocol.py:500: in sync_request
#     return self.async_request(handler, *args, timeout=timeout).value
# C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\rpyc\core\async_.py:102: in value
#     raise self._obj
# E   _get_exception_class.<locals>.Derived: cannot dump <member '____id_pack__' of 'BaseNetref' objects>
# E
# E   ========= Remote Traceback (1) =========
# E   Traceback (most recent call last):
# E     File "C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\rpyc\core\protocol.py", line 338, in _dispatch_request
# E       res = self._HANDLERS[handler](self, *args)
# E     File "C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\rpyc\core\protocol.py", line 630, in _handle_call
# E       return obj(*args, **dict(kwargs))
# E     File "C:\prog\modin\modin\pandas\dataframe.py", line 172, in __init__
# E       pandas_df = pandas.DataFrame(
# E     File "C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\pandas\core\frame.py", line 614, in __init__
# E       mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
# E     File "C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\pandas\core\internals\construction.py", line 416, in dict_to_mgr
# E       arrays = Series(data, index=columns, dtype=object)
# E     File "C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\pandas\core\series.py", line 405, in __init__
# E       data, index = self._init_dict(data, index, dtype)
# E     File "C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\pandas\core\series.py", line 502, in _init_dict
# E       s = s.reindex(index, copy=False)
# E     File "C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\pandas\core\series.py", line 4580, in reindex
# E       return super().reindex(index=index, **kwargs)
# E     File "C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\pandas\core\generic.py", line 4804, in reindex
# E       if all(
# E     File "C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\pandas\core\generic.py", line 4805, in <genexpr>
# E       self._get_axis(axis).identical(ax)
# E     File "C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\pandas\core\indexes\base.py", line 4819, in identical
# E       self.equals(other)
# E     File "C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\pandas\core\indexes\multi.py", line 3505, in equals
# E       if not np.array_equal(self_mask, other_mask):
# E     File "<__array_function__ internals>", line 5, in array_equal
# E     File "C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\rpyc\core\netref.py", line 277, in method
# E       return syncreq(_self, consts.HANDLE_CALLATTR, name, args, kwargs)
# E     File "C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\rpyc\core\netref.py", line 76, in syncreq
# E       return conn.sync_request(handler, proxy, *args)
# E     File "C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\rpyc\core\protocol.py", line 500, in sync_request
# E       return self.async_request(handler, *args, timeout=timeout).value
# E     File "C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\rpyc\core\protocol.py", line 524, in async_request
# E       self._async_request(handler, args, res)
# E     File "C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\rpyc\core\protocol.py", line 506, in _async_request
# E       self._send(consts.MSG_REQUEST, seq, (handler, self._box(args)))
# E     File "C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\rpyc\core\protocol.py", line 233, in _send
# E       data = brine.dump((msg, seq, args))
# E     File "C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\rpyc\core\brine.py", line 375, in dump
# E       _dump(obj, stream)
# E     File "C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\rpyc\core\brine.py", line 194, in _dump
# E       _dump_registry.get(type(obj), _undumpable)(obj, stream)
# E     File "C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\rpyc\core\brine.py", line 186, in _dump_tuple
# E       _dump(item, stream)
# E     File "C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\rpyc\core\brine.py", line 194, in _dump
# E       _dump_registry.get(type(obj), _undumpable)(obj, stream)
# E     File "C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\rpyc\core\brine.py", line 186, in _dump_tuple
# E       _dump(item, stream)
# E     File "C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\rpyc\core\brine.py", line 194, in _dump
# E       _dump_registry.get(type(obj), _undumpable)(obj, stream)
# E     File "C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\rpyc\core\brine.py", line 186, in _dump_tuple
# E       _dump(item, stream)
# E     File "C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\rpyc\core\brine.py", line 194, in _dump
# E       _dump_registry.get(type(obj), _undumpable)(obj, stream)
# E     File "C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\rpyc\core\brine.py", line 186, in _dump_tuple
# E       _dump(item, stream)
# E     File "C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\rpyc\core\brine.py", line 194, in _dump
# E       _dump_registry.get(type(obj), _undumpable)(obj, stream)
# E     File "C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\rpyc\core\brine.py", line 186, in _dump_tuple
# E       _dump(item, stream)
# E     File "C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\rpyc\core\brine.py", line 194, in _dump
# E       _dump_registry.get(type(obj), _undumpable)(obj, stream)
# E     File "C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\rpyc\core\brine.py", line 186, in _dump_tuple
# E       _dump(item, stream)
# E     File "C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\rpyc\core\brine.py", line 194, in _dump
# E       _dump_registry.get(type(obj), _undumpable)(obj, stream)
# E     File "C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\rpyc\core\brine.py", line 186, in _dump_tuple
# E       _dump(item, stream)
# E     File "C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\rpyc\core\brine.py", line 194, in _dump
# E       _dump_registry.get(type(obj), _undumpable)(obj, stream)
# E     File "C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\rpyc\core\brine.py", line 186, in _dump_tuple
# E       _dump(item, stream)
# E     File "C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\rpyc\core\brine.py", line 194, in _dump
# E       _dump_registry.get(type(obj), _undumpable)(obj, stream)
# E     File "C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\rpyc\core\brine.py", line 186, in _dump_tuple
# E       _dump(item, stream)
# E     File "C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\rpyc\core\brine.py", line 194, in _dump
# E       _dump_registry.get(type(obj), _undumpable)(obj, stream)
# E     File "C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\rpyc\core\brine.py", line 190, in _undumpable
# E       raise TypeError("cannot dump %r" % (obj,))
# E   TypeError: cannot dump <member '____id_pack__' of 'BaseNetref' objects>
