# %% [markdown]
# Specify the folder from where you want to import json for analysis

# %%
path_dir = 'json_analytics_from_test\\suit_windows_experimental'

# %%
# Get a list of tests in the folder
import os
list_files = tuple(os.walk(path_dir))[0][2]

# %% [markdown]
# The following block is needed to import the module from the parent folder

# %%
import os
import sys
import inspect

currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0, parentdir)

# %%
from ParseOutputPytest import ParseOutputPytest
pop = ParseOutputPytest()

# %% [markdown]
# Получим самые медленные тесты

# %%
max_durations = 300
for i in list_files:
    dict_name_duration = pop.get_dict_test_duration(f'{path_dir}/{i}')
    sorted_list_group = sorted(dict_name_duration.items(), key=lambda x: x[1], reverse=True)
    for name, duration in sorted_list_group[:10]:
        print(f'{name}\n    {duration}')
    print('\n')
# Out:
# modin/pandas/test/dataframe/test_binary.py::test_math_functions[add-rows-scalar]
#     0.11304840000000027
# modin/pandas/test/dataframe/test_binary.py::test_math_functions[radd-columns-series_or_list]
#     0.11302869999999965
# modin/pandas/test/dataframe/test_binary.py::test_math_functions_fill_value[rpow-None-check_missing_value]
#     0.09413179999999954
# modin/pandas/test/dataframe/test_binary.py::test_math_functions[add-rows-series_or_list]
#     0.0836560000000004
# modin/pandas/test/dataframe/test_binary.py::test_math_functions[rpow-rows-series_or_list]
#     0.08034259999999893
# modin/pandas/test/dataframe/test_binary.py::test_math_functions[rpow-columns-series_or_list]
#     0.07747659999999978
# modin/pandas/test/dataframe/test_binary.py::test_math_functions[mod-rows-series_or_list]
#     0.07504019999999922
# modin/pandas/test/dataframe/test_binary.py::test_math_functions[rmul-rows-series_or_list]
#     0.07476709999999898
# ...

# %% [markdown]
# Получим для каждого файла тесты, которые в сумме работают меньше 300 секунд

# %%
max_durations = 300
for i in list_files:
    dict_name_duration = pop.get_group_test_with_less_time(f'{path_dir}/{i}', max_durations)
    for name in dict_name_duration:
        print(f'{name}')
    print('\n')
# Out:
# modin/pandas/test/dataframe/test_binary.py::test_comparison
# modin/pandas/test/dataframe/test_binary.py::test_duplicate_indexes
# modin/pandas/test/dataframe/test_binary.py::test_equals
# modin/pandas/test/dataframe/test_binary.py::test_math_alias
# modin/pandas/test/dataframe/test_binary.py::test_math_functions
# modin/pandas/test/dataframe/test_binary.py::test_math_functions_fill_value
# modin/pandas/test/dataframe/test_binary.py::test_math_functions_level
# modin/pandas/test/dataframe/test_binary.py::test_mismatched_row_partitions
# modin/pandas/test/dataframe/test_binary.py::test_multi_level_comparison
#
#
# modin/pandas/test/dataframe/test_default.py::test___array__
# modin/pandas/test/dataframe/test_default.py::test___bool__
# modin/pandas/test/dataframe/test_default.py::test_asfreq
# modin/pandas/test/dataframe/test_default.py::test_assign
# modin/pandas/test/dataframe/test_default.py::test_at_time
# modin/pandas/test/dataframe/test_default.py::test_between_time
# ...
