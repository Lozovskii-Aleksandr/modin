# %% [markdown]
# # Merge the errors from different tests

# %% [markdown]
# Specify the folder from where you want to import json for analysis

# %%
path_dir = 'json_analytics_from_test'

# %% [markdown]
# Specify the number of the last lines for which to merge errors

# %%
number_line = 9

# %% [markdown]
# The following block is needed to import the module from the parent folder

# %%
import os
import sys
import inspect

currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0, parentdir)

# %%
from ParseOutputPytest import ParseOutputPytest
pop = ParseOutputPytest()

# %%
# Get a list of tests in the folder
import os
list_files = tuple(os.walk(path_dir))[0][2]

# %%
# Get for each file - dict
list_dict = []
for name_file_test in list_files:
    new_dict = pop.get_dict_name_with_error_text(f'{path_dir}\\{name_file_test}')
    list_dict.append(new_dict)

# Merge dicts in one dict
res_dict = {}
for dict_for_test in list_dict:
    res_dict.update(dict_for_test)
    
# Group the names by errors
res_dict_group = pop.get_dict_error_with_list_test(res_dict, number_line)

# %%
print("Total errors:  ", len(res_dict))
print("Unique errors: ", len(res_dict_group))
# Out:
# Total errors:   8934
# Unique errors:  135

# %%
pop.print_top_most_frequent_errors(res_dict, number_line, 10)
# Out:
# -----------------------------------------------------------------------
# ======= Remote Traceback =======
#  ...
# E     File "C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\rpyc\core\brine.py", line 194, in _dump
# E       _dump_registry.get(type(obj), _undumpable)(obj, stream)
# E     File "C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\rpyc\core\brine.py", line 186, in _dump_tuple
# E       _dump(item, stream)
# E     File "C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\rpyc\core\brine.py", line 194, in _dump
# E       _dump_registry.get(type(obj), _undumpable)(obj, stream)
# E     File "C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\rpyc\core\brine.py", line 190, in _undumpable
# E       raise TypeError("cannot dump %r" % (obj,))
# E   TypeError: cannot dump <member '____id_pack__' of 'BaseNetref' objects>
#
# Occurs in 3260 tests.
#      modin/pandas/test/dataframe/test_join_sort.py::test_sort_values[None-ignore_index_True-first-quicksort-inplace_True-ascending_True-over_rows_int-multiindex_level0-int_data]
#      modin/pandas/test/dataframe/test_join_sort.py::test_sort_values[None-ignore_index_True-first-quicksort-inplace_True-ascending_True-over_rows_int-multiindex_level0-float_nan_data]
#      modin/pandas/test/dataframe/test_join_sort.py::test_sort_values[None-ignore_index_True-first-quicksort-inplace_True-ascending_True-over_rows_int-multiindex_level1,multiindex_level0-int_data]
#      modin/pandas/test/dataframe/test_join_sort.py::test_sort_values[None-ignore_index_True-first-quicksort-inplace_True-ascending_True-over_rows_int-multiindex_level1,multiindex_level0-float_nan_data]
#      modin/pandas/test/dataframe/test_join_sort.py::test_sort_values[None-ignore_index_True-first-quicksort-inplace_True-ascending_True-over_rows_int-multiindex_level0,last,first,multiindex_level1-int_data]
# And also in 3255 tests.
# -----------------------------------------------------------------------
#
#
# -----------------------------------------------------------------------
# modin\pandas\test\test_series.py:187: in create_test_series
#     modin_series = pd.Series(vals[next(iter(vals.keys()))], **kwargs)
# modin\experimental\cloud\meta_magic.py:155: in __new__
#     return cls.__real_cls__(*a, **kw)
# modin\experimental\cloud\rpyc_proxy.py:431: in __init__
#     if hasattr(self, "_preprocess_init_args"):
# modin\experimental\cloud\rpyc_proxy.py:497: in __getattribute__
#     return getattr(dct["__remote_end__"], name)
# E   KeyError: '__remote_end__'
#
# Occurs in 1799 tests.
#      modin/pandas/test/test_series.py::test_to_frame[int_data]
#      modin/pandas/test/test_series.py::test_to_frame[float_nan_data]
#      modin/pandas/test/test_series.py::test_callable_key_in_getitem[int_data]
#      modin/pandas/test/test_series.py::test_callable_key_in_getitem[float_nan_data]
#      modin/pandas/test/test_series.py::test_T[int_data]
# And also in 1794 tests.
# -----------------------------------------------------------------------
#
#
# -----------------------------------------------------------------------
# ======= Remote Traceback =======
#  ...
# E     File "C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\rpyc\core\protocol.py", line 338, in _dispatch_request
# E       res = self._HANDLERS[handler](self, *args)
# E     File "C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\rpyc\core\protocol.py", line 630, in _handle_call
# E       return obj(*args, **dict(kwargs))
# E     File "C:\prog\modin\modin\experimental\cloud\rpyc_proxy.py", line 34, in _batch_loads
# E       return tuple(pickle.loads(item) for item in items)
# E     File "C:\prog\modin\modin\experimental\cloud\rpyc_proxy.py", line 34, in <genexpr>
# E       return tuple(pickle.loads(item) for item in items)
# E   AttributeError: type object '_DTypeMeta' has no attribute '_abstract'
#
# Occurs in 1634 tests.
#      modin/pandas/test/dataframe/test_indexing.py::test_loc_nested_assignment[int_data]
#      modin/pandas/test/dataframe/test_indexing.py::test_loc_nested_assignment[float_nan_data]
#      modin/pandas/test/dataframe/test_indexing.py::test_iloc_nested_assignment[int_data]
#      modin/pandas/test/dataframe/test_indexing.py::test_iloc_nested_assignment[float_nan_data]
#      modin/pandas/test/dataframe/test_indexing.py::test_pop[int_data]
# And also in 1629 tests.
# -----------------------------------------------------------------------
#
#
# -----------------------------------------------------------------------
# modin\pandas\test\test_series.py:190: in create_test_series
#     modin_series = pd.Series(vals, **kwargs)
# modin\experimental\cloud\meta_magic.py:155: in __new__
#     return cls.__real_cls__(*a, **kw)
# modin\experimental\cloud\rpyc_proxy.py:431: in __init__
#     if hasattr(self, "_preprocess_init_args"):
# modin\experimental\cloud\rpyc_proxy.py:497: in __getattribute__
#     return getattr(dct["__remote_end__"], name)
# E   KeyError: '__remote_end__'
#
# Occurs in 1137 tests.
#      modin/pandas/test/test_series.py::test___setitem___non_hashable[str_index-location_based_slice]
#      modin/pandas/test/test_series.py::test___setitem___non_hashable[str_index-index_based_slice]
#      modin/pandas/test/test_series.py::test___setitem___non_hashable[str_index-list_of_labels]
#      modin/pandas/test/test_series.py::test___setitem___non_hashable[str_index-boolean_mask]
#      modin/pandas/test/test_series.py::test___setitem___non_hashable[int_index-location_based_slice]
# And also in 1132 tests.
# -----------------------------------------------------------------------
#
#
# -----------------------------------------------------------------------
# ======= Remote Traceback =======
#  ...
# E     File "C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\rpyc\core\protocol.py", line 338, in _dispatch_request
# E       res = self._HANDLERS[handler](self, *args)
# E     File "C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\rpyc\core\protocol.py", line 630, in _handle_call
# E       return obj(*args, **dict(kwargs))
# E     File "C:\prog\modin\modin\experimental\cloud\rpyc_proxy.py", line 34, in _batch_loads
# E       return tuple(pickle.loads(item) for item in items)
# E     File "C:\prog\modin\modin\experimental\cloud\rpyc_proxy.py", line 34, in <genexpr>
# E       return tuple(pickle.loads(item) for item in items)
# E   AttributeError: type object 'ndarray' has no attribute '__iter__'
#
# Occurs in 120 tests.
#      modin/pandas/test/dataframe/test_indexing.py::test_rename_sanity
#      modin/pandas/test/dataframe/test_indexing.py::test_rename_inplace
#      modin/pandas/test/dataframe/test_indexing.py::test_rename_axis_inplace
#      modin/pandas/test/dataframe/test_indexing.py::test_reorder_levels
#      modin/pandas/test/dataframe/test_indexing.py::test_reindex_multiindex
# And also in 115 tests.
# -----------------------------------------------------------------------
#
#
# -----------------------------------------------------------------------
# E   _get_exception_class.<locals>.Derived: 'list' object is not callable
# E
# E   ========= Remote Traceback (1) =========
# E   Traceback (most recent call last):
# E     File "C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\rpyc\core\protocol.py", line 338, in _dispatch_request
# E       res = self._HANDLERS[handler](self, *args)
# E     File "C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\rpyc\core\protocol.py", line 630, in _handle_call
# E       return obj(*args, **dict(kwargs))
# E   TypeError: 'list' object is not callable
#
# Occurs in 117 tests.
#      modin/pandas/test/dataframe/test_default.py::test_take
#      modin/pandas/test/dataframe/test_indexing.py::test_asof_with_nan[subset2-dates0]
#      modin/pandas/test/dataframe/test_indexing.py::test_asof_with_nan[subset2-dates1]
#      modin/pandas/test/dataframe/test_indexing.py::test_asof_without_nan[subset2-dates0]
#      modin/pandas/test/dataframe/test_indexing.py::test_asof_without_nan[subset2-dates1]
# And also in 112 tests.
# -----------------------------------------------------------------------
#
#
# -----------------------------------------------------------------------
# ======= Remote Traceback =======
#  ...
# E     File "C:\prog\modin\modin\pandas\dataframe.py", line 172, in __init__
# E       pandas_df = pandas.DataFrame(
# E     File "C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\pandas\core\frame.py", line 702, in __init__
# E       mgr = arrays_to_mgr(
# E     File "C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\pandas\core\internals\construction.py", line 135, in arrays_to_mgr
# E       return create_block_manager_from_arrays(
# E     File "C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\pandas\core\internals\managers.py", line 1776, in create_block_manager_from_arrays
# E       raise construction_error(len(arrays), arrays[0].shape, axes, e)
# E   ValueError: Shape of passed values is (4, 4), indices imply (2, 4)
#
# Occurs in 77 tests.
#      modin/pandas/test/dataframe/test_reduction.py::test_prod[data0-over_rows_int-skipna_True-False-prod]
#      modin/pandas/test/dataframe/test_reduction.py::test_prod[data0-over_rows_int-skipna_True-False-product]
#      modin/pandas/test/dataframe/test_reduction.py::test_prod[data0-over_rows_int-skipna_True-True-prod]
#      modin/pandas/test/dataframe/test_reduction.py::test_prod[data0-over_rows_int-skipna_True-True-product]
#      modin/pandas/test/dataframe/test_reduction.py::test_prod[data0-over_rows_int-skipna_False-False-prod]
# And also in 72 tests.
# -----------------------------------------------------------------------
#
#
# -----------------------------------------------------------------------
# ======= Remote Traceback =======
#  ...
# E     File "C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\rpyc\core\protocol.py", line 656, in _handle_callattr
# E       return self._handle_call(obj, args, kwargs)
# E     File "C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\rpyc\core\protocol.py", line 630, in _handle_call
# E       return obj(*args, **dict(kwargs))
# E     File "C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\pandas\core\indexes\multi.py", line 2060, in __getitem__
# E       new_codes = [level_codes[key] for level_codes in self.codes]
# E     File "C:\Users\alozovsk\Anaconda3\envs\modin\lib\site-packages\pandas\core\indexes\multi.py", line 2060, in <listcomp>
# E       new_codes = [level_codes[key] for level_codes in self.codes]
# E   IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
#
# Occurs in 72 tests.
#      modin/pandas/test/dataframe/test_binary.py::test_math_functions_level[add]
#      modin/pandas/test/dataframe/test_binary.py::test_math_functions_level[radd]
#      modin/pandas/test/dataframe/test_binary.py::test_math_functions_level[sub]
#      modin/pandas/test/dataframe/test_binary.py::test_math_functions_level[rsub]
#      modin/pandas/test/dataframe/test_binary.py::test_math_functions_level[mod]
# And also in 67 tests.
# -----------------------------------------------------------------------
#
#
# -----------------------------------------------------------------------
# modin\pandas\test\test_series.py:370: in test___getitem_edge_cases
#     modin_series = pd.Series(data)
# modin\experimental\cloud\meta_magic.py:155: in __new__
#     return cls.__real_cls__(*a, **kw)
# modin\experimental\cloud\rpyc_proxy.py:431: in __init__
#     if hasattr(self, "_preprocess_init_args"):
# modin\experimental\cloud\rpyc_proxy.py:497: in __getattribute__
#     return getattr(dct["__remote_end__"], name)
# E   KeyError: '__remote_end__'
#
# Occurs in 64 tests.
#      modin/pandas/test/test_series.py::test___getitem_edge_cases[-7--7]
#      modin/pandas/test/test_series.py::test___getitem_edge_cases[-7--5]
#      modin/pandas/test/test_series.py::test___getitem_edge_cases[-7--3]
#      modin/pandas/test/test_series.py::test___getitem_edge_cases[-7-0]
#      modin/pandas/test/test_series.py::test___getitem_edge_cases[-7-None]
# And also in 59 tests.
# -----------------------------------------------------------------------
#
#
# -----------------------------------------------------------------------
# modin\experimental\cloud\rpyc_proxy.py:483: in __getattribute__
#     return oget(self, type(self))
# modin\experimental\cloud\rpyc_proxy.py:602: in iloc
#     return DeliveringILocIndexer(self.__remote_end__)
# modin\experimental\cloud\rpyc_proxy.py:431: in __init__
#     if hasattr(self, "_preprocess_init_args"):
# modin\experimental\cloud\rpyc_proxy.py:497: in __getattribute__
#     return getattr(dct["__remote_end__"], name)
# E   KeyError: '__remote_end__'
#
# Occurs in 59 tests.
#      modin/pandas/test/dataframe/test_binary.py::test_math_functions[add-columns-series_or_list]
#      modin/pandas/test/dataframe/test_binary.py::test_math_functions[radd-columns-series_or_list]
#      modin/pandas/test/dataframe/test_binary.py::test_math_functions[sub-columns-series_or_list]
#      modin/pandas/test/dataframe/test_binary.py::test_math_functions[rsub-columns-series_or_list]
#      modin/pandas/test/dataframe/test_binary.py::test_math_functions[mod-columns-series_or_list]
# And also in 54 tests.
# -----------------------------------------------------------------------
